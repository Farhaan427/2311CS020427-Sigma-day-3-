# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhaan427/2311CS020427-Sigma-day-3-/blob/main/Day_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Correct the import statement from 'skleran' to 'sklearn'
from sklearn.ensemble import IsolationForest
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data =sns.load_dataset("iris")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from scipy.stats import zscore

data=data.copy()
z_scores = np.abs(zscore(data.drop('species', axis=1)))
data = data[(z_scores < 3).all(axis=1)]

# %%
z_scores
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0        0.900681     1.019004      1.340227     1.315444
# 1        1.143017     0.131979      1.340227     1.315444
# 2        1.385353     0.328414      1.397064     1.315444
# 3        1.506521     0.098217      1.283389     1.315444
# 4        1.021849     1.249201      1.340227     1.315444
# ..            ...          ...           ...          ...
# 145      1.038005     0.131979      0.819596     1.448832
# 146      0.553333     1.282963      0.705921     0.922303
# 147      0.795669     0.131979      0.819596     1.053935
# 148      0.432165     0.788808      0.933271     1.448832
# 149      0.068662     0.131979      0.762758     0.790671
#
# [150 rows x 4 columns]

# %%
z_scores.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       0.833096     0.775262      0.888225     0.866315
# std        0.554981     0.633756      0.460948     0.501171
# min        0.052506     0.098217      0.023872     0.000878
# 25%        0.416010     0.328414      0.478571     0.395774
# 50%        0.795669     0.592373      1.018527     1.052180
# 75%        1.143017     1.200092      1.283389     1.315444
# max        2.492019     3.090775      1.785832     1.712096
