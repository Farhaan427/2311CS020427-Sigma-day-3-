# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhaan427/2311CS020427-Sigma-day-3-/blob/main/Day_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
movies_df = pd.read_csv('/content/Movie.csv')

# %%
movies_df
# Out:
#       userId             movie  rating
# 0          3  Toy Story (1995)     4.0
# 1          6  Toy Story (1995)     5.0
# 2          8  Toy Story (1995)     4.0
# 3         10  Toy Story (1995)     4.0
# 4         11  Toy Story (1995)     4.5
# ...      ...               ...     ...
# 8987    7087  GoldenEye (1995)     3.0
# 8988    7088  GoldenEye (1995)     1.0
# 8989    7105  GoldenEye (1995)     2.0
# 8990    7113  GoldenEye (1995)     3.0
# 8991    7117  GoldenEye (1995)     3.0
#
# [8992 rows x 3 columns]

# %%
movies_df.shape
# Out:
# (8992, 3)

# %%
movies_df.head()
# Out:
#    userId             movie  rating
# 0       3  Toy Story (1995)     4.0
# 1       6  Toy Story (1995)     5.0
# 2       8  Toy Story (1995)     4.0
# 3      10  Toy Story (1995)     4.0
# 4      11  Toy Story (1995)     4.5

# %%
movies_df[movies_df['userId']==3398]
# Out:
#       userId             movie  rating
# 1250    3398  Toy Story (1995)     4.0
# 5805    3398       Heat (1995)     5.0

# %%
movies_df[movies_df['userId']==6]
# Out:
#       userId                    movie  rating
# 1          6         Toy Story (1995)     5.0
# 3725       6  Grumpier Old Men (1995)     3.0
# 6464       6           Sabrina (1995)     5.0

# %%
len(movies_df.userId.unique())
# Out:
# 4081

# %%
len(movies_df.movie.unique())
# Out:
# 10

# %%
movies_df.movie.unique()
# Out:
# array(['Toy Story (1995)', 'Jumanji (1995)', 'Grumpier Old Men (1995)',
#        'Waiting to Exhale (1995)', 'Father of the Bride Part II (1995)',
#        'Heat (1995)', 'Sabrina (1995)', 'Tom and Huck (1995)',
#        'Sudden Death (1995)', 'GoldenEye (1995)'], dtype=object)

# %%
user_movies_df = movies_df.pivot(index='userId',
                                 columns='movie',
                                 values='rating').reset_index(drop=True)

# %%
user_movies_df
# Out:
# movie  Father of the Bride Part II (1995)  GoldenEye (1995)  \
# 0                                     NaN               NaN
# 1                                     NaN               NaN
# 2                                     NaN               NaN
# 3                                     NaN               4.0
# 4                                     NaN               NaN
# ...                                   ...               ...
# 4076                                  4.0               NaN
# 4077                                  3.5               NaN
# 4078                                  NaN               3.0
# 4079                                  NaN               NaN
# 4080                                  NaN               NaN
#
# movie  Grumpier Old Men (1995)  Heat (1995)  Jumanji (1995)  Sabrina (1995)  \
# 0                          NaN          NaN             3.5             NaN
# 1                          4.0          NaN             NaN             NaN
# ...

# %%
user_movies_df.index = movies_df.userId.unique()

# %%
user_movies_df
# Out:
# movie  Father of the Bride Part II (1995)  GoldenEye (1995)  \
# 3                                     NaN               NaN
# 6                                     NaN               NaN
# 8                                     NaN               NaN
# 10                                    NaN               4.0
# 11                                    NaN               NaN
# ...                                   ...               ...
# 7044                                  4.0               NaN
# 7070                                  3.5               NaN
# 7080                                  NaN               3.0
# 7087                                  NaN               NaN
# 7105                                  NaN               NaN
#
# movie  Grumpier Old Men (1995)  Heat (1995)  Jumanji (1995)  Sabrina (1995)  \
# 3                          NaN          NaN             3.5             NaN
# 6                          4.0          NaN             NaN             NaN
# ...
