# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhaan427/2311CS020427-Sigma-day-3-/blob/main/DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix

# %%
data = pd.read_csv(r"/content/Heart_Disease_Dataset.csv", on_bad_lines='warn') # Show a warning and skip the line
# Out:
# <ipython-input-3-d5f292e17ee0>:1: ParserWarning: Skipping line 22899: expected 18 fields, saw 21
#
#   data = pd.read_csv(r"/content/Heart_Disease_Dataset.csv", on_bad_lines='warn') # Show a warning and skip the line
# <ipython-input-3-d5f292e17ee0>:1: ParserWarning: Skipping line 34338: expected 18 fields, saw 23
# Skipping line 45828: expected 18 fields, saw 22
# Skipping line 57269: expected 18 fields, saw 19
#
#   data = pd.read_csv(r"/content/Heart_Disease_Dataset.csv", on_bad_lines='warn') # Show a warning and skip the line
# <ipython-input-3-d5f292e17ee0>:1: ParserWarning: Skipping line 80217: expected 18 fields, saw 30
#
#   data = pd.read_csv(r"/content/Heart_Disease_Dataset.csv", on_bad_lines='warn') # Show a warning and skip the line
# <ipython-input-3-d5f292e17ee0>:1: DtypeWarning: Columns (1,5,6,14) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No              7
# 1          Yes  36.93     Yes             Yes     No              3
# 2           No   18.7     Yes              No    Yes             26
# 3          Yes  31.43     Yes             Yes    Yes             24
# 4          Yes  75.64      No              No    Yes              2
#
#   MentalHealth DiffWalking     Sex AgeCategory  \
# 0            6         Yes  Female       25-29
# 1           10          No  Female       30-34
# 2           15          No    Male       70-74
# 3           20          No  Female       40-44
# 4           29          No    Male       35-39
#
#                              Race                 Diabetic PhysicalActivity  \
# 0                           White                      Yes              Yes
# 1                        Hispanic  No, borderline diabetes              Yes
# ...

# %%
data.shape
# Out:
# (143065, 18)

# %%
data.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke PhysicalHealth  \
# 143060           No  48.02      No              No    Yes             13
# 143061          Yes  82.88      No              No     No             29
# 143062           No  39.46      No             Yes    Yes             23
# 143063           No  46.25     Yes             Yes    Yes              9
# 143064           No  39.26     Yes              No     No             10
#
#        MentalHealth DiffWalking     Sex  AgeCategory  \
# 143060           17          No  Female        45-49
# 143061           23          No    Male        75-79
# 143062            6         Yes    Male  80 or older
# 143063           14          No    Male        25-29
# 143064            5         Yes  Female        25-29
#
#                                   Race                 Diabetic  \
# 143060                           White  No, borderline diabetes
# 143061                           Other  No, borderline diabetes
# ...

# %%
data.describe()
# Out:
#        HeartDisease     BMI Smoking AlcoholDrinking  Stroke  PhysicalHealth  \
# count        143065  143065  143065          143065  143065          143064
# unique            3   16560       3               2       3              61
# top             Yes   27.95     Yes             Yes     Yes              15
# freq          71664      24   72067           72144   71655            3784
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# count         143063      143063  143063       143063    143063
# unique            61           3       3           14         7
# top               27         Yes  Female  80 or older  Hispanic
# freq            3811       71577   71703        11213     23993
#
#                        Diabetic PhysicalActivity GenHealth  SleepTime  Asthma  \
# count                    143063           143063    143063   143063.0  143063
# unique                        4                3         6      463.0       2
# ...

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      1
# MentalHealth        2
# DiffWalking         2
# Sex                 2
# AgeCategory         2
# Race                2
# Diabetic            2
# PhysicalActivity    2
# GenHealth           2
# SleepTime           2
# Asthma              2
# KidneyDisease       2
# SkinCancer          3
# dtype: int64

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 143060    False
# 143061    False
# 143062    False
# 143063    False
# 143064    False
# Length: 143065, dtype: bool

# %%
len(data[data.duplicated()])
# Out:
# 0

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
for coloumn in data.columns:
  print(coloumn,data[coloumn].unique())
# Out:
# HeartDisease ['Yes' 'No' '05']
# BMI [14.96 36.93 18.7 ... '80.42' '20.25' 69.41]
# Smoking ['Yes' 'No' '22.8']
# AlcoholDrinking ['Yes' 'No']
# Stroke ['No' 'Yes' '5']
# PhysicalHealth [7 3 26 24 2 12 5 6 19 11 8 16 20 4 15 1 9 14 27 0 17 28 29 23 18 10 25 21
#  22 13 '23' '5' '12' '17' '10' '4' '29' '11' '2' '14' '16' '1' '26' '20'
#  '8' '24' '28' '27' '0' '13' '3' '19' '25' '22' '18' '9' '15' '6' '21' '7'
#  nan 'Yes']
# MentalHealth [6 10 15 20 29 27 13 7 2 25 11 26 12 28 14 22 16 5 1 0 24 9 21 23 8 4 3 17
#  18 19 nan '22' '15' '4' '6' '21' '5' '24' '12' '2' '17' '29' '27' '20'
#  '16' '26' '3' '11' '10' '1' '25' '28' '8' '19' '13' '7' '23' '9' '14' '0'
#  '18' 'No']
# DiffWalking ['Yes' 'No' nan 'Male']
# Sex ['Female' 'Male' nan '30-34']
# AgeCategory ['25-29' '30-34' '70-74' '40-44' '35-39' '50-54' '75-79' '60-64' '18-24'
#  '55-59' '65-69' '45-49' '80 or older' nan 'Hispanic']
# Race ['White' 'Hispanic' 'American Indian/Alaskan Native' 'Black' 'Asian'
#  'Other' nan 'Yes']
# ...

# %%
for coloumn in data.columns:
  print(data[coloumn].value_counts())
# Out:
# HeartDisease
# Yes    71664
# No     71400
# 05         1
# Name: count, dtype: int64
# BMI
# 27.95    24
# 56.95    22
# 71.52    22
# 56.38    22
# 90.16    22
#          ..
# 29.15     1
# 80.14     1
# 69.82     1
# 27.72     1
# 69.41     1
# Name: count, Length: 16560, dtype: int64
# Smoking
# Yes     72067
# No      70997
# 22.8        1
# Name: count, dtype: int64
# AlcoholDrinking
# Yes    72144
# No     70921
# Name: count, dtype: int64
# Stroke
# Yes    71655
# No     71409
# 5          1
# Name: count, dtype: int64
# PhysicalHealth
# 15     3784
# 20     3778
# 8      3753
# 12     3743
# 16     3743
#        ...
# 15     1062
# 29     1046
# 25     1041
# 2      1024
# Yes       1
# Name: count, Length: 61, dtype: int64
# MentalHealth
# 27    3811
# 13    3795
# 16    3777
# 1     3747
# 21    3746
#       ...
# 9     1064
# 12    1054
# 10    1039
# 4     1024
# No       1
# Name: count, Length: 61, dtype: int64
# DiffWalking
# Yes     71577
# No      71485
# ...
